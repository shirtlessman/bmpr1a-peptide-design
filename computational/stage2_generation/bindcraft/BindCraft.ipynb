# %% [markdown]
# # BindCraft: Protein binder design
#
# <img src="https://github.com/martinpacesa/BindCraft/blob/main/pipeline.png?raw=true">
#
# Simple binder design pipeline using AlphaFold2 backpropagation, MPNN, and PyRosetta. Select your target and let the script do the rest of the work and finish once you have enough designs to order!
#
# The designs will be saved on your Google Drive under BindCraft/[design_name]/ and you can continue running the design pipeline if the session times out and it will continue adding new designs.

# %%
#@title Installation
# %%time
import os, time, gc, io
import contextlib
import json
from datetime import datetime
from ipywidgets import HTML, VBox
from IPython.display import display

if not os.path.isfile("bindcraft/params/done.txt"):
  print("Installing required BindCraft components")

  print("Pulling BindCraft code from Github")
  os.makedirs('/content/bindcraft/', exist_ok=True)
  # !git clone https://github.com/martinpacesa/BindCraft /content/bindcraft/
  os.system("chmod +x /content/bindcraft/functions/dssp")
  os.system("chmod +x /content/bindcraft/functions/DAlphaBall.gcc")

  print("Installing ColabDesign")
  os.system("(mkdir bindcraft/params; apt-get install aria2 -qq; \
  aria2c -q -x 16 https://storage.googleapis.com/alphafold/alphafold_params_2022-12-06.tar; \
  tar -xf alphafold_params_2022-12-06.tar -C bindcraft/params; touch bindcraft/params/done.txt )&")
  os.system("pip install git+https://github.com/sokrypton/ColabDesign.git")
  # for debugging purposes
  os.system("ln -s /usr/local/lib/python3.*/dist-packages/colabdesign colabdesign")

  print("Installing PyRosetta")
  os.system("pip install pyrosetta_installer")
  with contextlib.redirect_stdout(io.StringIO()):
    import pyrosetta_installer
    pyrosetta_installer.install_pyrosetta(serialization=True)

  # download params
  if not os.path.isfile("bindcraft/params/done.txt"):
    print("downloading AlphaFold params")
    while not os.path.isfile("bindcraft/params/done.txt"):
      time.sleep(5)

  print("BindCraft installation is finished, ready to run!")
else:
  print("BindCraft components already installed, ready to run!")
# Out:
# Installing required BindCraft components
# Pulling BindCraft code from Github
# Cloning into '/content/bindcraft'...
# remote: Enumerating objects: 442, done.
# remote: Counting objects: 100% (209/209), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 442 (delta 192), reused 160 (delta 160), pack-reused 233 (from 2)
# Receiving objects: 100% (442/442), 5.65 MiB | 13.56 MiB/s, done.
# Resolving deltas: 100% (282/282), done.
# Installing ColabDesign
# Installing PyRosetta
# BindCraft installation is finished, ready to run!
# CPU times: user 13.1 ms, sys: 12 ms, total: 25.1 ms
# Wall time: 3min 4s

# %%
#@title Mount your Google Drive to save design results
from google.colab import drive
drive.mount('/content/drive')
currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Google drive mounted at: {currenttime}")

bindcraft_google_drive = '/content/drive/My Drive/BindCraft/'
os.makedirs(bindcraft_google_drive, exist_ok=True)
print("BindCraft folder successfully created in your drive!")
# Out:
# Mounted at /content/drive
# Google drive mounted at: 2026-03-21 13:18:35
# BindCraft folder successfully created in your drive!

# %%
#@title Binder design settings
# @markdown ---
# @markdown Enter path where to save your designs. We recommend to save on Google drive so that you can continue generating at any time.
design_path = "/content/drive/MyDrive/BindCraft/BMPR1A/" # @param {"type":"string","placeholder":"/content/drive/MyDrive/BindCraft/PDL1/"}

# @markdown Enter the name that should be prefixed to your binders (generally target name).
binder_name = "BMPR1A" # @param {"type":"string","placeholder":"PDL1"}

# @markdown The path to the .pdb structure of your target. Can be an experimental or AlphaFold2 structure. We recommend trimming the structure to as small as needed, as the whole selected chains will be backpropagated through the network and can significantly increase running times.
starting_pdb = "/content/1REW_BMPR1A_bindcraft.pdb" # @param {"type":"string","placeholder":"/content/bindcraft/example/PDL1.pdb"}

# @markdown Which chains of your PDB to target? Can be one or multiple, in a comma-separated format. Other chains will be ignored during design.
chains = "A" # @param {"type":"string","placeholder":"A,C"}

# @markdown What positions to target in your protein of interest? For example `1,2-10` or chain specific `A1-10,B1-20` or entire chains `A`. If left blank, an appropriate site will be selected by the pipeline.
target_hotspot_residues = "34,42-46,53-57,60,62,64,77-79,81-83,85,86,89,90,92-95,97,99" # @param {"type":"string","placeholder":""}

# @markdown What is the minimum and maximum size of binders you want to design? Pipeline will randomly sample different sizes between these values.
lengths = "10,30" # @param {"type":"string","placeholder":"70,150"}

# @markdown How many binder designs passing filters do you require?
number_of_final_designs = 10 # @param {"type":"integer","placeholder":"100"}
# @markdown ---
# @markdown Enter path on your Google drive (/content/drive/MyDrive/BindCraft/[binder_name].json) to previous target settings to continue design campaign. If left empty, it will use the settings above and generate a new settings json in your design output folder.
load_previous_target_settings = "" # @param {"type":"string","placeholder":""}
# @markdown ---

if load_previous_target_settings:
    target_settings_path = load_previous_target_settings
else:
    lengths = [int(x.strip()) for x in lengths.split(',') if len(lengths.split(',')) == 2]

    if len(lengths) != 2:
        raise ValueError("Incorrect specification of binder lengths.")

    settings = {
        "design_path": design_path,
        "binder_name": binder_name,
        "starting_pdb": starting_pdb,
        "chains": chains,
        "target_hotspot_residues": target_hotspot_residues,
        "lengths": lengths,
        "number_of_final_designs": number_of_final_designs
    }

    target_settings_path = os.path.join(design_path, binder_name+".json")
    os.makedirs(design_path, exist_ok=True)

    with open(target_settings_path, 'w') as f:
        json.dump(settings, f, indent=4)

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Binder design settings updated at: {currenttime}")
print(f"New .json file with target settings has been generated in: {target_settings_path}")
# Out:
# Binder design settings updated at: 2026-03-21 13:18:43
# New .json file with target settings has been generated in: /content/drive/MyDrive/BindCraft/BMPR1A/BMPR1A.json

# %%
#@title Advanced settings
# @markdown ---
# @markdown Which binder design protocol to run? Default is recommended. "Beta-sheet" promotes the design of more beta sheeted proteins, but requires more sampling. "Peptide" is optimised for helical peptide binders.
design_protocol = "Peptide" # @param ["Default","Beta-sheet","Peptide"]
# @markdown What prediction protocol to use?. "Default" performs single sequence prediction of the binder. "HardTarget" uses initial guess to improve complex prediction for difficult targets, but might introduce some bias.
prediction_protocol = "Default" # @param ["Default","HardTarget"]
# @markdown What interface design method to use?. "AlphaFold2" is the default, interface is generated by AlphaFold2. "MPNN" uses soluble MPNN to optimise the interface.
interface_protocol = "AlphaFold2" # @param ["AlphaFold2","MPNN"]
# @markdown What target template protocol to use? "Default" allows for limited amount flexibility. "Masked" allows for greater target flexibility on both sidechain and backbone level.
template_protocol = "Default" # @param ["Default","Masked"]
# @markdown ---

if design_protocol == "Default":
    design_protocol_tag = "default_4stage_multimer"
elif design_protocol == "Beta-sheet":
    design_protocol_tag = "betasheet_4stage_multimer"
elif design_protocol == "Peptide":
    design_protocol_tag = "peptide_3stage_multimer"
else:
    raise ValueError(f"Unsupported design protocol")

if interface_protocol == "AlphaFold2":
    interface_protocol_tag = ""
elif interface_protocol == "MPNN":
    interface_protocol_tag = "_mpnn"
else:
    raise ValueError(f"Unsupported interface protocol")

if template_protocol == "Default":
    template_protocol_tag = ""
elif template_protocol == "Masked":
    template_protocol_tag = "_flexible"
else:
    raise ValueError(f"Unsupported template protocol")

if design_protocol in ["Peptide"]:
    prediction_protocol_tag = ""
else:
    if prediction_protocol == "Default":
        prediction_protocol_tag = ""
    elif prediction_protocol == "HardTarget":
        prediction_protocol_tag = "_hardtarget"
    else:
        raise ValueError(f"Unsupported prediction protocol")

advanced_settings_path = "/content/bindcraft/settings_advanced/" + design_protocol_tag + interface_protocol_tag + template_protocol_tag + prediction_protocol_tag + ".json"

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Advanced design settings updated at: {currenttime}")
# Out:
# Advanced design settings updated at: 2026-03-21 13:18:46

# %%
#@title Filters
# @markdown ---
# @markdown Which filters for designs to use? "Default" are recommended, "Peptide" are for the design of peptide binders, "Relaxed" are more permissive but may result in fewer experimental successes, "Peptide_Relaxed" are more permissive filters for non-helical peptides, "None" is for benchmarking.
filter_option = "Peptide" # @param ["Default", "Peptide", "Relaxed", "Peptide_Relaxed", "None"]
# @markdown ---

if filter_option == "Default":
    filter_settings_path = "/content/bindcraft/settings_filters/default_filters.json"
elif filter_option == "Peptide":
    filter_settings_path = "/content/bindcraft/settings_filters/peptide_filters.json"
elif filter_option == "Relaxed":
    filter_settings_path = "/content/bindcraft/settings_filters/relaxed_filters.json"
elif filter_option == "Peptide_Relaxed":
    filter_settings_path = "/content/bindcraft/settings_filters/peptide_relaxed_filters.json"
elif filter_option == "None":
    filter_settings_path = "/content/bindcraft/settings_filters/no_filters.json"
else:
    raise ValueError(f"Unsupported filter type")

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Filter settings updated at: {currenttime}")
# Out:
# Filter settings updated at: 2026-03-21 13:18:49

# %% [markdown]
# # Everything is set, BindCraft is ready to run!

# %%
# @title Import functions and settings
from bindcraft.functions import *

args = {"settings":target_settings_path,
        "filters":filter_settings_path,
        "advanced":advanced_settings_path}

# Check if JAX-capable GPU is available, otherwise exit
check_jax_gpu()

# perform checks of input setting files
settings_path, filters_path, advanced_path = (args["settings"], args["filters"], args["advanced"])

### load settings from JSON
target_settings, advanced_settings, filters = load_json_settings(settings_path, filters_path, advanced_path)

settings_file = os.path.basename(settings_path).split('.')[0]
filters_file = os.path.basename(filters_path).split('.')[0]
advanced_file = os.path.basename(advanced_path).split('.')[0]

### load AF2 model settings
design_models, prediction_models, multimer_validation = load_af2_models(advanced_settings["use_multimer_design"])

### perform checks on advanced_settings
bindcraft_folder = "colab"
advanced_settings = perform_advanced_settings_check(advanced_settings, bindcraft_folder)

### generate directories, design path names can be found within the function
design_paths = generate_directories(target_settings["design_path"])

### generate dataframes
trajectory_labels, design_labels, final_labels = generate_dataframe_labels()

trajectory_csv = os.path.join(target_settings["design_path"], 'trajectory_stats.csv')
mpnn_csv = os.path.join(target_settings["design_path"], 'mpnn_design_stats.csv')
final_csv = os.path.join(target_settings["design_path"], 'final_design_stats.csv')
failure_csv = os.path.join(target_settings["design_path"], 'failure_csv.csv')

create_dataframe(trajectory_csv, trajectory_labels)
create_dataframe(mpnn_csv, design_labels)
create_dataframe(final_csv, final_labels)
generate_filter_pass_csv(failure_csv, args["filters"])

currenttime = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Loaded design functions and settings at: {currenttime}")
# Out:
# Available GPUs:
# NVIDIA H100 80GB HBM31: gpu
# Loaded design functions and settings at: 2026-03-21 13:18:56

# %%
#@title Initialise PyRosetta

####################################
####################################
####################################
### initialise PyRosetta
pr.init(f'-ignore_unrecognized_res -ignore_zero_occupancy -mute all -holes:dalphaball {advanced_settings["dalphaball_path"]} -corrections::beta_nov16 true -relax:default_repeats 1')
# Out:
# ┌───────────────────────────────────────────────────────────────────────────────┐
# │                                  PyRosetta-4                                  │
# │               Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │               (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                               │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRES PURCHASE OF A LICENSE │
# │          See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └───────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2026 [Rosetta PyRosetta4.Release.python312.ubuntu.cxx11thread.serialization 2026.06+release.e5a76a2dbd7e42e1271d0af460926c86e29e59d1 2026-02-02T18:21:37] retrieved from: http://www.pyrosetta.org

# %%
#@title Run BindCraft!
####################################
###################### BindCraft Run
####################################
# Colab-specific: live displays
num_sampled_trajectories = len(pd.read_csv(trajectory_csv))
num_accepted_designs = len(pd.read_csv(final_csv))
sampled_trajectories_label = HTML(value=f"<h3 style='color: #1f77b4;'>Sampled Trajectories: <span style='color: #1f77b4;'>{num_sampled_trajectories}</span></h3>")
accepted_designs_label = HTML(value=f"<h3 style='color: #2ca02c;'>Accepted Designs: <span style='color: #2ca02c;'>{num_accepted_designs}</span></h3>")
display(VBox([sampled_trajectories_label, accepted_designs_label]))

# initialise counters
script_start_time = time.time()
trajectory_n = 1
accepted_designs = 0

### start design loop
while True:
    ### check if we have the target number of binders
    final_designs_reached = check_accepted_designs(design_paths, mpnn_csv, final_labels, final_csv, advanced_settings, target_settings, design_labels)

    if final_designs_reached:
        # stop design loop execution
        break

    ### check if we reached maximum allowed trajectories
    max_trajectories_reached = check_n_trajectories(design_paths, advanced_settings)

    if max_trajectories_reached:
        break

    ### Initialise design
    # measure time to generate design
    trajectory_start_time = time.time()

    # generate random seed to vary designs
    seed = int(np.random.randint(0, high=999999, size=1, dtype=int)[0])

    # sample binder design length randomly from defined distribution
    samples = np.arange(min(target_settings["lengths"]), max(target_settings["lengths"]) + 1)
    length = np.random.choice(samples)

    # load desired helicity value to sample different secondary structure contents
    helicity_value = load_helicity(advanced_settings)

    # generate design name and check if same trajectory was already run
    design_name = target_settings["binder_name"] + "_l" + str(length) + "_s"+ str(seed)
    trajectory_dirs = ["Trajectory", "Trajectory/Relaxed", "Trajectory/LowConfidence", "Trajectory/Clashing"]
    trajectory_exists = any(os.path.exists(os.path.join(design_paths[trajectory_dir], design_name + ".pdb")) for trajectory_dir in trajectory_dirs)

    if not trajectory_exists:
        print("Starting trajectory: "+design_name)

        ### Begin binder hallucination
        trajectory = binder_hallucination(design_name, target_settings["starting_pdb"], target_settings["chains"],
                                            target_settings["target_hotspot_residues"], length, seed, helicity_value,
                                            design_models, advanced_settings, design_paths, failure_csv)
        trajectory_metrics = copy_dict(trajectory._tmp["best"]["aux"]["log"]) # contains plddt, ptm, i_ptm, pae, i_pae
        trajectory_pdb = os.path.join(design_paths["Trajectory"], design_name + ".pdb")

        # round the metrics to two decimal places
        trajectory_metrics = {k: round(v, 2) if isinstance(v, float) else v for k, v in trajectory_metrics.items()}

        # time trajectory
        trajectory_time = time.time() - trajectory_start_time
        trajectory_time_text = f"{'%d hours, %d minutes, %d seconds' % (int(trajectory_time // 3600), int((trajectory_time % 3600) // 60), int(trajectory_time % 60))}"
        print("Starting trajectory took: "+trajectory_time_text)
        print("")

        # Proceed if there is no trajectory termination signal
        if trajectory.aux["log"]["terminate"] == "":
            # Relax binder to calculate statistics
            trajectory_relaxed = os.path.join(design_paths["Trajectory/Relaxed"], design_name + ".pdb")
            pr_relax(trajectory_pdb, trajectory_relaxed)

            # define binder chain, placeholder in case multi-chain parsing in ColabDesign gets changed
            binder_chain = "B"

            # Calculate clashes before and after relaxation
            num_clashes_trajectory = calculate_clash_score(trajectory_pdb)
            num_clashes_relaxed = calculate_clash_score(trajectory_relaxed)

            # secondary structure content of starting trajectory binder and interface
            trajectory_alpha, trajectory_beta, trajectory_loops, trajectory_alpha_interface, trajectory_beta_interface, trajectory_loops_interface, trajectory_i_plddt, trajectory_ss_plddt = calc_ss_percentage(trajectory_pdb, advanced_settings, binder_chain)

            # analyze interface scores for relaxed af2 trajectory
            trajectory_interface_scores, trajectory_interface_AA, trajectory_interface_residues = score_interface(trajectory_relaxed, binder_chain)

            # starting binder sequence
            trajectory_sequence = trajectory.get_seq(get_best=True)[0]

            # analyze sequence
            traj_seq_notes = validate_design_sequence(trajectory_sequence, num_clashes_relaxed, advanced_settings)

            # target structure RMSD compared to input PDB
            trajectory_target_rmsd = unaligned_rmsd(target_settings["starting_pdb"], trajectory_pdb, target_settings["chains"], 'A')

            # save trajectory statistics into CSV
            trajectory_data = [design_name, advanced_settings["design_algorithm"], length, seed, helicity_value, target_settings["target_hotspot_residues"], trajectory_sequence, trajectory_interface_residues,
                                trajectory_metrics['plddt'], trajectory_metrics['ptm'], trajectory_metrics['i_ptm'], trajectory_metrics['pae'], trajectory_metrics['i_pae'],
                                trajectory_i_plddt, trajectory_ss_plddt, num_clashes_trajectory, num_clashes_relaxed, trajectory_interface_scores['binder_score'],
                                trajectory_interface_scores['surface_hydrophobicity'], trajectory_interface_scores['interface_sc'], trajectory_interface_scores['interface_packstat'],
                                trajectory_interface_scores['interface_dG'], trajectory_interface_scores['interface_dSASA'], trajectory_interface_scores['interface_dG_SASA_ratio'],
                                trajectory_interface_scores['interface_fraction'], trajectory_interface_scores['interface_hydrophobicity'], trajectory_interface_scores['interface_nres'], trajectory_interface_scores['interface_interface_hbonds'],
                                trajectory_interface_scores['interface_hbond_percentage'], trajectory_interface_scores['interface_delta_unsat_hbonds'], trajectory_interface_scores['interface_delta_unsat_hbonds_percentage'],
                                trajectory_alpha_interface, trajectory_beta_interface, trajectory_loops_interface, trajectory_alpha, trajectory_beta, trajectory_loops, trajectory_interface_AA, trajectory_target_rmsd,
                                trajectory_time_text, traj_seq_notes, settings_file, filters_file, advanced_file]
            insert_data(trajectory_csv, trajectory_data)

            if advanced_settings["enable_mpnn"]:
                # initialise MPNN counters
                mpnn_n = 1
                accepted_mpnn = 0
                mpnn_dict = {}
                design_start_time = time.time()

                ### MPNN redesign of starting binder
                mpnn_trajectories = mpnn_gen_sequence(trajectory_pdb, binder_chain, trajectory_interface_residues, advanced_settings)
                existing_mpnn_sequences = set(pd.read_csv(mpnn_csv, usecols=['Sequence'])['Sequence'].values)

                # create set of MPNN sequences with allowed amino acid composition
                restricted_AAs = set(aa.strip().upper() for aa in advanced_settings["omit_AAs"].split(',')) if advanced_settings["force_reject_AA"] else set()

                mpnn_sequences = sorted({
                    mpnn_trajectories['seq'][n][-length:]: {
                        'seq': mpnn_trajectories['seq'][n][-length:],
                        'score': mpnn_trajectories['score'][n],
                        'seqid': mpnn_trajectories['seqid'][n]
                    } for n in range(advanced_settings["num_seqs"])
                    if (not restricted_AAs or not any(aa in mpnn_trajectories['seq'][n][-length:].upper() for aa in restricted_AAs))
                    and mpnn_trajectories['seq'][n][-length:] not in existing_mpnn_sequences
                }.values(), key=lambda x: x['score'])

                del existing_mpnn_sequences

                # check whether any sequences are left after amino acid rejection and duplication check, and if yes proceed with prediction
                if mpnn_sequences:
                    # add optimisation for increasing recycles if trajectory is beta sheeted
                    if advanced_settings["optimise_beta"] and float(trajectory_beta) > 15:
                        advanced_settings["num_recycles_validation"] = advanced_settings["optimise_beta_recycles_valid"]

                    ### Compile prediction models once for faster prediction of MPNN sequences
                    clear_mem()
                    # compile complex prediction model
                    complex_prediction_model = mk_afdesign_model(protocol="binder", num_recycles=advanced_settings["num_recycles_validation"], data_dir=advanced_settings["af_params_dir"],
                                                                use_multimer=multimer_validation)
                    complex_prediction_model.prep_inputs(pdb_filename=target_settings["starting_pdb"], chain=target_settings["chains"], binder_len=length, rm_target_seq=advanced_settings["rm_template_seq_predict"],
                                                        rm_target_sc=advanced_settings["rm_template_sc_predict"])

                    # compile binder monomer prediction model
                    binder_prediction_model = mk_afdesign_model(protocol="hallucination", use_templates=False, initial_guess=False,
                                                                use_initial_atom_pos=False, num_recycles=advanced_settings["num_recycles_validation"],
                                                                data_dir=advanced_settings["af_params_dir"], use_multimer=multimer_validation)
                    binder_prediction_model.prep_inputs(length=length)

                    # iterate over designed sequences
                    for mpnn_sequence in mpnn_sequences:
                        mpnn_time = time.time()

                        # generate mpnn design name numbering
                        mpnn_design_name = design_name + "_mpnn" + str(mpnn_n)
                        mpnn_score = round(mpnn_sequence['score'],2)
                        mpnn_seqid = round(mpnn_sequence['seqid'],2)

                        # add design to dictionary
                        mpnn_dict[mpnn_design_name] = {'seq': mpnn_sequence['seq'], 'score': mpnn_score, 'seqid': mpnn_seqid}

                        # save fasta sequence
                        if advanced_settings["save_mpnn_fasta"] is True:
                            save_fasta(mpnn_design_name, mpnn_sequence['seq'], design_paths)

                        ### Predict mpnn redesigned binder complex using masked templates
                        mpnn_complex_statistics, pass_af2_filters = predict_binder_complex(complex_prediction_model,
                                                                                        mpnn_sequence['seq'], mpnn_design_name,
                                                                                        target_settings["starting_pdb"], target_settings["chains"],
                                                                                        length, trajectory_pdb, prediction_models, advanced_settings,
                                                                                        filters, design_paths, failure_csv)

                        # if AF2 filters are not passed then skip the scoring
                        if not pass_af2_filters:
                            print(f"Base AF2 filters not passed for {mpnn_design_name}, skipping interface scoring")
                            mpnn_n += 1
                            continue

                        # calculate statistics for each model individually
                        for model_num in prediction_models:
                            mpnn_design_pdb = os.path.join(design_paths["MPNN"], f"{mpnn_design_name}_model{model_num+1}.pdb")
                            mpnn_design_relaxed = os.path.join(design_paths["MPNN/Relaxed"], f"{mpnn_design_name}_model{model_num+1}.pdb")

                            if os.path.exists(mpnn_design_pdb):
                                # Calculate clashes before and after relaxation
                                num_clashes_mpnn = calculate_clash_score(mpnn_design_pdb)
                                num_clashes_mpnn_relaxed = calculate_clash_score(mpnn_design_relaxed)

                                # analyze interface scores for relaxed af2 trajectory
                                mpnn_interface_scores, mpnn_interface_AA, mpnn_interface_residues = score_interface(mpnn_design_relaxed, binder_chain)

                                # secondary structure content of starting trajectory binder
                                mpnn_alpha, mpnn_beta, mpnn_loops, mpnn_alpha_interface, mpnn_beta_interface, mpnn_loops_interface, mpnn_i_plddt, mpnn_ss_plddt = calc_ss_percentage(mpnn_design_pdb, advanced_settings, binder_chain)

                                # unaligned RMSD calculate to determine if binder is in the designed binding site
                                rmsd_site = unaligned_rmsd(trajectory_pdb, mpnn_design_pdb, binder_chain, binder_chain)

                                # calculate RMSD of target compared to input PDB
                                target_rmsd = target_pdb_rmsd(mpnn_design_pdb, target_settings["starting_pdb"], target_settings["chains"])

                                # add the additional statistics to the mpnn_complex_statistics dictionary
                                mpnn_complex_statistics[model_num+1].update({
                                    'i_pLDDT': mpnn_i_plddt,
                                    'ss_pLDDT': mpnn_ss_plddt,
                                    'Unrelaxed_Clashes': num_clashes_mpnn,
                                    'Relaxed_Clashes': num_clashes_mpnn_relaxed,
                                    'Binder_Energy_Score': mpnn_interface_scores['binder_score'],
                                    'Surface_Hydrophobicity': mpnn_interface_scores['surface_hydrophobicity'],
                                    'ShapeComplementarity': mpnn_interface_scores['interface_sc'],
                                    'PackStat': mpnn_interface_scores['interface_packstat'],
                                    'dG': mpnn_interface_scores['interface_dG'],
                                    'dSASA': mpnn_interface_scores['interface_dSASA'],
                                    'dG/dSASA': mpnn_interface_scores['interface_dG_SASA_ratio'],
                                    'Interface_SASA_%': mpnn_interface_scores['interface_fraction'],
                                    'Interface_Hydrophobicity': mpnn_interface_scores['interface_hydrophobicity'],
                                    'n_InterfaceResidues': mpnn_interface_scores['interface_nres'],
                                    'n_InterfaceHbonds': mpnn_interface_scores['interface_interface_hbonds'],
                                    'InterfaceHbondsPercentage': mpnn_interface_scores['interface_hbond_percentage'],
                                    'n_InterfaceUnsatHbonds': mpnn_interface_scores['interface_delta_unsat_hbonds'],
                                    'InterfaceUnsatHbondsPercentage': mpnn_interface_scores['interface_delta_unsat_hbonds_percentage'],
                                    'InterfaceAAs': mpnn_interface_AA,
                                    'Interface_Helix%': mpnn_alpha_interface,
                                    'Interface_BetaSheet%': mpnn_beta_interface,
                                    'Interface_Loop%': mpnn_loops_interface,
                                    'Binder_Helix%': mpnn_alpha,
                                    'Binder_BetaSheet%': mpnn_beta,
                                    'Binder_Loop%': mpnn_loops,
                                    'Hotspot_RMSD': rmsd_site,
                                    'Target_RMSD': target_rmsd
                                })

                                # save space by removing unrelaxed predicted mpnn complex pdb?
                                if advanced_settings["remove_unrelaxed_complex"]:
                                    os.remove(mpnn_design_pdb)

                        # calculate complex averages
                        mpnn_complex_averages = calculate_averages(mpnn_complex_statistics, handle_aa=True)

                        ### Predict binder alone in single sequence mode
                        binder_statistics = predict_binder_alone(binder_prediction_model, mpnn_sequence['seq'], mpnn_design_name, length,
                                                                trajectory_pdb, binder_chain, prediction_models, advanced_settings, design_paths)

                        # extract RMSDs of binder to the original trajectory
                        for model_num in prediction_models:
                            mpnn_binder_pdb = os.path.join(design_paths["MPNN/Binder"], f"{mpnn_design_name}_model{model_num+1}.pdb")

                            if os.path.exists(mpnn_binder_pdb):
                                rmsd_binder = unaligned_rmsd(trajectory_pdb, mpnn_binder_pdb, binder_chain, "A")

                            # append to statistics
                            binder_statistics[model_num+1].update({
                                    'Binder_RMSD': rmsd_binder
                                })

                            # save space by removing binder monomer models?
                            if advanced_settings["remove_binder_monomer"]:
                                os.remove(mpnn_binder_pdb)

                        # calculate binder averages
                        binder_averages = calculate_averages(binder_statistics)

                        # analyze sequence to make sure there are no cysteins and it contains residues that absorb UV for detection
                        seq_notes = validate_design_sequence(mpnn_sequence['seq'], mpnn_complex_averages.get('Relaxed_Clashes', None), advanced_settings)

                        # measure time to generate design
                        mpnn_end_time = time.time() - mpnn_time
                        elapsed_mpnn_text = f"{'%d hours, %d minutes, %d seconds' % (int(mpnn_end_time // 3600), int((mpnn_end_time % 3600) // 60), int(mpnn_end_time % 60))}"


                        # Insert statistics about MPNN design into CSV, will return None if corresponding model does note exist
                        model_numbers = range(1, 6)
                        statistics_labels = ['pLDDT', 'pTM', 'i_pTM', 'pAE', 'i_pAE', 'i_pLDDT', 'ss_pLDDT', 'Unrelaxed_Clashes', 'Relaxed_Clashes', 'Binder_Energy_Score', 'Surface_Hydrophobicity',
                                            'ShapeComplementarity', 'PackStat', 'dG', 'dSASA', 'dG/dSASA', 'Interface_SASA_%', 'Interface_Hydrophobicity', 'n_InterfaceResidues', 'n_InterfaceHbonds', 'InterfaceHbondsPercentage',
                                            'n_InterfaceUnsatHbonds', 'InterfaceUnsatHbondsPercentage', 'Interface_Helix%', 'Interface_BetaSheet%', 'Interface_Loop%', 'Binder_Helix%',
                                            'Binder_BetaSheet%', 'Binder_Loop%', 'InterfaceAAs', 'Hotspot_RMSD', 'Target_RMSD']

                        # Initialize mpnn_data with the non-statistical data
                        mpnn_data = [mpnn_design_name, advanced_settings["design_algorithm"], length, seed, helicity_value, target_settings["target_hotspot_residues"], mpnn_sequence['seq'], mpnn_interface_residues, mpnn_score, mpnn_seqid]

                        # Add the statistical data for mpnn_complex
                        for label in statistics_labels:
                            mpnn_data.append(mpnn_complex_averages.get(label, None))
                            for model in model_numbers:
                                mpnn_data.append(mpnn_complex_statistics.get(model, {}).get(label, None))

                        # Add the statistical data for binder
                        for label in ['pLDDT', 'pTM', 'pAE', 'Binder_RMSD']:  # These are the labels for binder alone
                            mpnn_data.append(binder_averages.get(label, None))
                            for model in model_numbers:
                                mpnn_data.append(binder_statistics.get(model, {}).get(label, None))

                        # Add the remaining non-statistical data
                        mpnn_data.extend([elapsed_mpnn_text, seq_notes, settings_file, filters_file, advanced_file])

                        # insert data into csv
                        insert_data(mpnn_csv, mpnn_data)

                        # find best model number by pLDDT
                        plddt_values = {i: mpnn_data[i] for i in range(11, 15) if mpnn_data[i] is not None}

                        # Find the key with the highest value
                        highest_plddt_key = int(max(plddt_values, key=plddt_values.get))

                        # Output the number part of the key
                        best_model_number = highest_plddt_key - 10
                        best_model_pdb = os.path.join(design_paths["MPNN/Relaxed"], f"{mpnn_design_name}_model{best_model_number}.pdb")

                        # run design data against filter thresholds
                        filter_conditions = check_filters(mpnn_data, design_labels, filters)
                        if filter_conditions == True:
                            print(mpnn_design_name+" passed all filters")
                            accepted_mpnn += 1
                            accepted_designs += 1

                            # copy designs to accepted folder
                            shutil.copy(best_model_pdb, design_paths["Accepted"])

                            # insert data into final csv
                            final_data = [''] + mpnn_data
                            insert_data(final_csv, final_data)

                            # copy animation from accepted trajectory
                            if advanced_settings["save_design_animations"]:
                                accepted_animation = os.path.join(design_paths["Accepted/Animation"], f"{design_name}.html")
                                if not os.path.exists(accepted_animation):
                                    shutil.copy(os.path.join(design_paths["Trajectory/Animation"], f"{design_name}.html"), accepted_animation)

                            # copy plots of accepted trajectory
                            plot_files = os.listdir(design_paths["Trajectory/Plots"])
                            plots_to_copy = [f for f in plot_files if f.startswith(design_name) and f.endswith('.png')]
                            for accepted_plot in plots_to_copy:
                                source_plot = os.path.join(design_paths["Trajectory/Plots"], accepted_plot)
                                target_plot = os.path.join(design_paths["Accepted/Plots"], accepted_plot)
                                if not os.path.exists(target_plot):
                                    shutil.copy(source_plot, target_plot)

                        else:
                            print(f"Unmet filter conditions for {mpnn_design_name}")
                            failure_df = pd.read_csv(failure_csv)
                            special_prefixes = ('Average_', '1_', '2_', '3_', '4_', '5_')
                            incremented_columns = set()

                            for column in filter_conditions:
                                base_column = column
                                for prefix in special_prefixes:
                                    if column.startswith(prefix):
                                        base_column = column.split('_', 1)[1]

                                if base_column not in incremented_columns:
                                    failure_df[base_column] = failure_df[base_column] + 1
                                    incremented_columns.add(base_column)

                            failure_df.to_csv(failure_csv, index=False)
                            shutil.copy(best_model_pdb, design_paths["Rejected"])

                        # increase MPNN design number
                        mpnn_n += 1

                        # if enough mpnn sequences of the same trajectory pass filters then stop
                        if accepted_mpnn >= advanced_settings["max_mpnn_sequences"]:
                            break

                    if accepted_mpnn >= 1:
                        print("Found "+str(accepted_mpnn)+" MPNN designs passing filters")
                    else:
                        print("No accepted MPNN designs found for this trajectory.")

                else:
                    print('Duplicate MPNN designs sampled with different trajectory, skipping current trajectory optimisation')

                # save space by removing unrelaxed design trajectory PDB
                if advanced_settings["remove_unrelaxed_trajectory"]:
                    os.remove(trajectory_pdb)

                # measure time it took to generate designs for one trajectory
                design_time = time.time() - design_start_time
                design_time_text = f"{'%d hours, %d minutes, %d seconds' % (int(design_time // 3600), int((design_time % 3600) // 60), int(design_time % 60))}"
                print("Design and validation of trajectory "+design_name+" took: "+design_time_text)

            # analyse the rejection rate of trajectories to see if we need to readjust the design weights
            if trajectory_n >= advanced_settings["start_monitoring"] and advanced_settings["enable_rejection_check"]:
                acceptance = accepted_designs / trajectory_n
                if not acceptance >= advanced_settings["acceptance_rate"]:
                    print("The ratio of successful designs is lower than defined acceptance rate! Consider changing your design settings!")
                    print("Script execution stopping...")
                    break

        # increase trajectory number
        trajectory_n += 1

        # Colab-specific: update counters
        num_sampled_trajectories = len(pd.read_csv(trajectory_csv))
        num_accepted_designs = len(pd.read_csv(final_csv))
        sampled_trajectories_label.value = f"Sampled trajectories: {num_sampled_trajectories}"
        accepted_designs_label.value = f"Accepted designs: {num_accepted_designs}"

### Script finished
elapsed_time = time.time() - script_start_time
elapsed_text = f"{'%d hours, %d minutes, %d seconds' % (int(elapsed_time // 3600), int((elapsed_time % 3600) // 60), int(elapsed_time % 60))}"
print("Finished all designs. Script execution for "+str(trajectory_n)+" trajectories took: "+elapsed_text)
# Out:
# VBox(children=(HTML(value="<h3 style='color: #1f77b4;'>Sampled Trajectories: <span style='color: #1f77b4;'>14<…
# Starting trajectory: BMPR1A_l10_s637859
# Stage 1: running (logits → soft)
# 1 models [1] recycles 0 hard 0 soft 0.01 temp 1 loss 5.61 helix 2.76 pae 0.53 i_pae 0.56 con 1.07 i_con 4.03 plddt 0.27 ptm 0.74 i_ptm 0.14
# 2 models [1] recycles 0 hard 0 soft 0.03 temp 1 loss 5.23 helix 2.31 pae 0.58 i_pae 0.60 con 1.05 i_con 4.09 plddt 0.27 ptm 0.75 i_ptm 0.11
# 3 models [0] recycles 0 hard 0 soft 0.04 temp 1 loss 5.21 helix 2.21 pae 0.59 i_pae 0.65 con 1.09 i_con 4.15 plddt 0.25 ptm 0.73 i_ptm 0.09
# 4 models [4] recycles 0 hard 0 soft 0.05 temp 1 loss 5.49 helix 2.55 pae 0.59 i_pae 0.63 con 1.07 i_con 4.11 plddt 0.29 ptm 0.73 i_ptm 0.11
# 5 models [0] recycles 0 hard 0 soft 0.07 temp 1 loss 4.83 helix 2.05 pae 0.52 i_pae 0.53 con 0.96 i_con 3.94 plddt 0.30 ptm 0.74 i_ptm 0.17
# 6 models [1] recycles 0 hard 0 soft 0.08 temp 1 loss 5.01 helix 1.98 pae 0.58 i_pae 0.63 con 1.07 i_con 4.23 plddt 0.29 ptm 0.72 i_ptm 0.12
# 7 models [2] recycles 0 hard 0 soft 0.09 temp 1 loss 4.75 helix 1.86 pae 0.58 i_pae 0.60 con 0.96 i_con 4.06 plddt 0.26 ptm 0.69 i_ptm 0.13
# 8 models [2] recycles 0 hard 0 soft 0.11 temp 1 loss 4.34 helix 1.45 pae 0.56 i_pae 0.59 con 0.97 i_con 4.04 plddt 0.31 ptm 0.70 i_ptm 0.14
# 9 models [1] recycles 0 hard 0 soft 0.12 temp 1 loss 4.52 helix 1.70 pae 0.51 i_pae 0.53 con 0.99 i_con 3.98 plddt 0.35 ptm 0.73 i_ptm 0.18
# 10 models [0] recycles 0 hard 0 soft 0.13 temp 1 loss 3.82 helix 1.09 pae 0.46 i_pae 0.47 con 0.93 i_con 3.88 plddt 0.38 ptm 0.74 i_ptm 0.22
# 11 models [0] recycles 0 hard 0 soft 0.15 temp 1 loss 3.88 helix 1.16 pae 0.47 i_pae 0.48 con 0.93 i_con 3.86 plddt 0.39 ptm 0.74 i_ptm 0.21
# 12 models [3] recycles 0 hard 0 soft 0.16 temp 1 loss 4.02 helix 1.17 pae 0.55 i_pae 0.58 con 0.92 i_con 3.99 plddt 0.34 ptm 0.73 i_ptm 0.14
# 13 models [1] recycles 0 hard 0 soft 0.17 temp 1 loss 4.36 helix 1.20 pae 0.60 i_pae 0.65 con 0.98 i_con 4.50 plddt 0.33 ptm 0.72 i_ptm 0.11
# 14 models [3] recycles 0 hard 0 soft 0.19 temp 1 loss 3.99 helix 1.18 pae 0.52 i_pae 0.54 con 0.95 i_con 3.96 plddt 0.38 ptm 0.72 i_ptm 0.19
# 15 models [2] recycles 0 hard 0 soft 0.20 temp 1 loss 3.81 helix 0.97 pae 0.54 i_pae 0.55 con 0.93 i_con 3.98 plddt 0.38 ptm 0.71 i_ptm 0.17
# 16 models [1] recycles 0 hard 0 soft 0.21 temp 1 loss 3.62 helix 0.85 pae 0.46 i_pae 0.48 con 1.01 i_con 3.87 plddt 0.39 ptm 0.75 i_ptm 0.22
# 17 models [3] recycles 0 hard 0 soft 0.23 temp 1 loss 3.63 helix 0.99 pae 0.46 i_pae 0.47 con 0.87 i_con 3.77 plddt 0.41 ptm 0.73 i_ptm 0.26
# 18 models [2] recycles 0 hard 0 soft 0.24 temp 1 loss 3.45 helix 0.72 pae 0.45 i_pae 0.47 con 0.92 i_con 3.85 plddt 0.41 ptm 0.72 i_ptm 0.26
# 19 models [3] recycles 0 hard 0 soft 0.25 temp 1 loss 3.66 helix 0.90 pae 0.48 i_pae 0.50 con 0.93 i_con 3.88 plddt 0.35 ptm 0.74 i_ptm 0.22
# 20 models [1] recycles 0 hard 0 soft 0.27 temp 1 loss 3.85 helix 0.83 pae 0.59 i_pae 0.63 con 0.99 i_con 4.21 plddt 0.38 ptm 0.71 i_ptm 0.11
# 21 models [4] recycles 0 hard 0 soft 0.28 temp 1 loss 3.66 helix 0.90 pae 0.50 i_pae 0.52 con 0.91 i_con 3.90 plddt 0.40 ptm 0.74 i_ptm 0.20
# 22 models [4] recycles 0 hard 0 soft 0.29 temp 1 loss 3.62 helix 0.76 pae 0.54 i_pae 0.57 con 0.92 i_con 4.00 plddt 0.40 ptm 0.73 i_ptm 0.17
# 23 models [3] recycles 0 hard 0 soft 0.31 temp 1 loss 3.55 helix 0.79 pae 0.49 i_pae 0.51 con 0.92 i_con 3.87 plddt 0.38 ptm 0.73 i_ptm 0.21
# 24 models [4] recycles 0 hard 0 soft 0.32 temp 1 loss 3.64 helix 0.86 pae 0.50 i_pae 0.52 con 0.95 i_con 3.90 plddt 0.43 ptm 0.74 i_ptm 0.22
# 25 models [2] recycles 0 hard 0 soft 0.33 temp 1 loss 3.60 helix 0.68 pae 0.58 i_pae 0.61 con 0.91 i_con 4.07 plddt 0.40 ptm 0.70 i_ptm 0.12
# 26 models [1] recycles 0 hard 0 soft 0.35 temp 1 loss 4.05 helix 0.88 pae 0.62 i_pae 0.67 con 1.02 i_con 4.41 plddt 0.35 ptm 0.71 i_ptm 0.09
# 27 models [2] recycles 0 hard 0 soft 0.36 temp 1 loss 3.72 helix 0.72 pae 0.59 i_pae 0.63 con 0.96 i_con 4.17 plddt 0.34 ptm 0.70 i_ptm 0.12
# 28 models [4] recycles 0 hard 0 soft 0.37 temp 1 loss 3.60 helix 0.73 pae 0.53 i_pae 0.56 con 0.92 i_con 4.05 plddt 0.43 ptm 0.73 i_ptm 0.17
# 29 models [0] recycles 0 hard 0 soft 0.39 temp 1 loss 3.50 helix 0.67 pae 0.51 i_pae 0.54 con 0.88 i_con 4.02 plddt 0.40 ptm 0.73 i_ptm 0.15
# 30 models [1] recycles 0 hard 0 soft 0.40 temp 1 loss 3.39 helix 0.62 pae 0.47 i_pae 0.50 con 0.90 i_con 3.92 plddt 0.42 ptm 0.73 i_ptm 0.19
# 31 models [2] recycles 0 hard 0 soft 0.41 temp 1 loss 3.57 helix 0.68 pae 0.55 i_pae 0.58 con 0.90 i_con 4.05 plddt 0.38 ptm 0.70 i_ptm 0.14
# 32 models [3] recycles 0 hard 0 soft 0.43 temp 1 loss 3.63 helix 0.86 pae 0.51 i_pae 0.54 con 0.88 i_con 3.91 plddt 0.39 ptm 0.72 i_ptm 0.19
# 33 models [1] recycles 0 hard 0 soft 0.44 temp 1 loss 3.84 helix 0.63 pae 0.62 i_pae 0.68 con 0.96 i_con 4.55 plddt 0.39 ptm 0.72 i_ptm 0.10
# 34 models [0] recycles 0 hard 0 soft 0.45 temp 1 loss 3.53 helix 0.66 pae 0.51 i_pae 0.53 con 0.98 i_con 4.00 plddt 0.42 ptm 0.74 i_ptm 0.16
# 35 models [4] recycles 0 hard 0 soft 0.47 temp 1 loss 3.44 helix 0.70 pae 0.51 i_pae 0.54 con 0.80 i_con 3.94 plddt 0.45 ptm 0.73 i_ptm 0.19
# 36 models [0] recycles 0 hard 0 soft 0.48 temp 1 loss 3.40 helix 0.58 pae 0.49 i_pae 0.51 con 0.94 i_con 3.96 plddt 0.42 ptm 0.73 i_ptm 0.17
# 37 models [0] recycles 0 hard 0 soft 0.49 temp 1 loss 3.31 helix 0.55 pae 0.47 i_pae 0.50 con 0.86 i_con 3.92 plddt 0.42 ptm 0.72 i_ptm 0.18
# 38 models [0] recycles 1 hard 0 soft 0.51 temp 1 loss 3.43 helix 0.67 pae 0.47 i_pae 0.50 con 0.92 i_con 3.89 plddt 0.45 ptm 0.74 i_ptm 0.21
# 39 models [3] recycles 1 hard 0 soft 0.52 temp 1 loss 3.59 helix 0.74 pae 0.53 i_pae 0.55 con 0.95 i_con 3.99 plddt 0.42 ptm 0.72 i_ptm 0.18
# 40 models [4] recycles 1 hard 0 soft 0.53 temp 1 loss 3.56 helix 0.70 pae 0.54 i_pae 0.58 con 0.85 i_con 4.07 plddt 0.45 ptm 0.73 i_ptm 0.17
# 41 models [0] recycles 1 hard 0 soft 0.55 temp 1 loss 3.23 helix 0.48 pae 0.49 i_pae 0.52 con 0.81 i_con 3.95 plddt 0.45 ptm 0.74 i_ptm 0.20
# 42 models [2] recycles 1 hard 0 soft 0.56 temp 1 loss 3.60 helix 0.67 pae 0.58 i_pae 0.62 con 0.86 i_con 4.16 plddt 0.41 ptm 0.70 i_ptm 0.14
# 43 models [4] recycles 1 hard 0 soft 0.57 temp 1 loss 3.47 helix 0.62 pae 0.54 i_pae 0.58 con 0.85 i_con 4.06 plddt 0.46 ptm 0.74 i_ptm 0.18
# 44 models [3] recycles 1 hard 0 soft 0.59 temp 1 loss 3.48 helix 0.68 pae 0.51 i_pae 0.53 con 0.88 i_con 3.97 plddt 0.45 ptm 0.73 i_ptm 0.19
# 45 models [2] recycles 1 hard 0 soft 0.60 temp 1 loss 3.65 helix 0.73 pae 0.59 i_pae 0.62 con 0.80 i_con 4.19 plddt 0.41 ptm 0.70 i_ptm 0.13
# 46 models [2] recycles 1 hard 0 soft 0.61 temp 1 loss 3.47 helix 0.62 pae 0.54 i_pae 0.58 con 0.82 i_con 4.09 plddt 0.43 ptm 0.71 i_ptm 0.16
# 47 models [4] recycles 1 hard 0 soft 0.63 temp 1 loss 3.57 helix 0.74 pae 0.54 i_pae 0.57 con 0.83 i_con 4.04 plddt 0.42 ptm 0.74 i_ptm 0.17
# 48 models [1] recycles 1 hard 0 soft 0.64 temp 1 loss 3.33 helix 0.57 pae 0.46 i_pae 0.49 con 0.89 i_con 3.93 plddt 0.47 ptm 0.74 i_ptm 0.22
# 49 models [0] recycles 1 hard 0 soft 0.65 temp 1 loss 3.29 helix 0.59 pae 0.47 i_pae 0.50 con 0.77 i_con 3.93 plddt 0.46 ptm 0.74 i_ptm 0.20
# 50 models [4] recycles 1 hard 0 soft 0.67 temp 1 loss 3.53 helix 0.61 pae 0.53 i_pae 0.57 con 1.00 i_con 4.04 plddt 0.45 ptm 0.73 i_ptm 0.17
# 51 models [3] recycles 1 hard 0 soft 0.68 temp 1 loss 3.28 helix 0.59 pae 0.51 i_pae 0.54 con 0.67 i_con 3.98 plddt 0.46 ptm 0.73 i_ptm 0.19
# 52 models [0] recycles 1 hard 0 soft 0.69 temp 1 loss 3.19 helix 0.46 pae 0.49 i_pae 0.52 con 0.73 i_con 3.98 plddt 0.44 ptm 0.74 i_ptm 0.18
# 53 models [2] recycles 1 hard 0 soft 0.71 temp 1 loss 3.42 helix 0.61 pae 0.54 i_pae 0.58 con 0.74 i_con 4.09 plddt 0.47 ptm 0.71 i_ptm 0.17
# 54 models [2] recycles 1 hard 0 soft 0.72 temp 1 loss 3.46 helix 0.66 pae 0.53 i_pae 0.56 con 0.76 i_con 4.07 plddt 0.45 ptm 0.71 i_ptm 0.18
# 55 models [2] recycles 1 hard 0 soft 0.73 temp 1 loss 3.40 helix 0.66 pae 0.52 i_pae 0.54 con 0.74 i_con 3.99 plddt 0.44 ptm 0.72 i_ptm 0.19
# 56 models [2] recycles 1 hard 0 soft 0.75 temp 1 loss 3.33 helix 0.59 pae 0.51 i_pae 0.54 con 0.72 i_con 3.98 plddt 0.44 ptm 0.71 i_ptm 0.17
# 57 models [3] recycles 1 hard 0 soft 0.76 temp 1 loss 3.10 helix 0.54 pae 0.44 i_pae 0.46 con 0.65 i_con 3.80 plddt 0.47 ptm 0.75 i_ptm 0.25
# 58 models [1] recycles 1 hard 0 soft 0.77 temp 1 loss 3.78 helix 0.60 pae 0.61 i_pae 0.68 con 0.78 i_con 4.68 plddt 0.41 ptm 0.73 i_ptm 0.11
# 59 models [4] recycles 1 hard 0 soft 0.79 temp 1 loss 3.34 helix 0.68 pae 0.47 i_pae 0.50 con 0.75 i_con 3.88 plddt 0.46 ptm 0.74 i_ptm 0.24
# 60 models [0] recycles 1 hard 0 soft 0.80 temp 1 loss 3.23 helix 0.63 pae 0.43 i_pae 0.45 con 0.78 i_con 3.78 plddt 0.43 ptm 0.74 i_ptm 0.25
# 61 models [3] recycles 1 hard 0 soft 0.81 temp 1 loss 3.05 helix 0.54 pae 0.40 i_pae 0.42 con 0.68 i_con 3.72 plddt 0.50 ptm 0.74 i_ptm 0.29
# 62 models [0] recycles 1 hard 0 soft 0.83 temp 1 loss 3.06 helix 0.51 pae 0.42 i_pae 0.45 con 0.71 i_con 3.76 plddt 0.51 ptm 0.74 i_ptm 0.26
# 63 models [0] recycles 1 hard 0 soft 0.84 temp 1 loss 3.13 helix 0.52 pae 0.43 i_pae 0.46 con 0.74 i_con 3.80 plddt 0.46 ptm 0.74 i_ptm 0.24
# 64 models [1] recycles 1 hard 0 soft 0.85 temp 1 loss 3.52 helix 0.57 pae 0.58 i_pae 0.62 con 0.77 i_con 4.25 plddt 0.37 ptm 0.74 i_ptm 0.11
# 65 models [0] recycles 1 hard 0 soft 0.87 temp 1 loss 3.05 helix 0.56 pae 0.41 i_pae 0.43 con 0.63 i_con 3.74 plddt 0.49 ptm 0.74 i_ptm 0.27
# 66 models [3] recycles 1 hard 0 soft 0.88 temp 1 loss 3.08 helix 0.59 pae 0.39 i_pae 0.42 con 0.70 i_con 3.70 plddt 0.52 ptm 0.74 i_ptm 0.30
# 67 models [3] recycles 1 hard 0 soft 0.89 temp 1 loss 3.05 helix 0.59 pae 0.39 i_pae 0.41 con 0.67 i_con 3.67 plddt 0.53 ptm 0.74 i_ptm 0.31
# 68 models [0] recycles 1 hard 0 soft 0.91 temp 1 loss 3.18 helix 0.57 pae 0.45 i_pae 0.47 con 0.68 i_con 3.86 plddt 0.46 ptm 0.75 i_ptm 0.22
# 69 models [2] recycles 1 hard 0 soft 0.92 temp 1 loss 3.46 helix 0.71 pae 0.52 i_pae 0.55 con 0.77 i_con 3.97 plddt 0.43 ptm 0.70 i_ptm 0.18
# 70 models [1] recycles 1 hard 0 soft 0.93 temp 1 loss 3.26 helix 0.74 pae 0.39 i_pae 0.40 con 0.81 i_con 3.67 plddt 0.52 ptm 0.76 i_ptm 0.33
# 71 models [1] recycles 1 hard 0 soft 0.95 temp 1 loss 3.57 helix 0.89 pae 0.45 i_pae 0.47 con 0.87 i_con 3.83 plddt 0.46 ptm 0.75 i_ptm 0.27
# 72 models [2] recycles 1 hard 0 soft 0.96 temp 1 loss 3.26 helix 0.59 pae 0.49 i_pae 0.51 con 0.72 i_con 3.90 plddt 0.46 ptm 0.70 i_ptm 0.20
# 73 models [4] recycles 1 hard 0 soft 0.97 temp 1 loss 3.30 helix 0.69 pae 0.45 i_pae 0.47 con 0.78 i_con 3.79 plddt 0.49 ptm 0.75 i_ptm 0.26
# 74 models [3] recycles 1 hard 0 soft 0.99 temp 1 loss 3.33 helix 0.68 pae 0.46 i_pae 0.47 con 0.80 i_con 3.84 plddt 0.47 ptm 0.74 i_ptm 0.24
# 75 models [0] recycles 1 hard 0 soft 1 temp 1 loss 3.30 helix 0.75 pae 0.42 i_pae 0.44 con 0.77 i_con 3.74 plddt 0.49 ptm 0.75 i_ptm 0.28
# Stage 2: running (soft → hard)
# 76 models [4] recycles 1 hard 0 soft 1 temp 0.96 loss 3.53 helix 0.80 pae 0.52 i_pae 0.53 con 0.75 i_con 3.95 plddt 0.38 ptm 0.74 i_ptm 0.19
# 77 models [3] recycles 1 hard 0 soft 1 temp 0.91 loss 3.19 helix 0.57 pae 0.46 i_pae 0.48 con 0.74 i_con 3.81 plddt 0.45 ptm 0.73 i_ptm 0.24
# 78 models [0] recycles 1 hard 0 soft 1 temp 0.87 loss 3.34 helix 0.76 pae 0.42 i_pae 0.44 con 0.77 i_con 3.79 plddt 0.48 ptm 0.74 i_ptm 0.27
# 79 models [2] recycles 1 hard 0 soft 1 temp 0.83 loss 3.94 helix 1.20 pae 0.49 i_pae 0.50 con 0.92 i_con 3.90 plddt 0.44 ptm 0.72 i_ptm 0.23
# 80 models [4] recycles 1 hard 0 soft 1 temp 0.79 loss 3.60 helix 0.92 pae 0.47 i_pae 0.49 con 0.87 i_con 3.83 plddt 0.45 ptm 0.74 i_ptm 0.24
# 81 models [1] recycles 1 hard 0 soft 1 temp 0.75 loss 3.36 helix 0.64 pae 0.48 i_pae 0.51 con 0.80 i_con 3.94 plddt 0.44 ptm 0.75 i_ptm 0.20
# 82 models [4] recycles 1 hard 0 soft 1 temp 0.72 loss 3.20 helix 0.63 pae 0.47 i_pae 0.49 con 0.60 i_con 3.83 plddt 0.44 ptm 0.75 i_ptm 0.22
# 83 models [1] recycles 1 hard 0 soft 1 temp 0.68 loss 3.07 helix 0.53 pae 0.40 i_pae 0.42 con 0.71 i_con 3.76 plddt 0.48 ptm 0.76 i_ptm 0.29
# 84 models [0] recycles 1 hard 0 soft 1 temp 0.64 loss 3.20 helix 0.59 pae 0.44 i_pae 0.46 con 0.76 i_con 3.80 plddt 0.46 ptm 0.74 i_ptm 0.25
# 85 models [0] recycles 1 hard 0 soft 1 temp 0.61 loss 2.79 helix 0.46 pae 0.34 i_pae 0.36 con 0.57 i_con 3.58 plddt 0.58 ptm 0.77 i_ptm 0.38
# 86 models [3] recycles 1 hard 0 soft 1 temp 0.58 loss 3.25 helix 0.62 pae 0.46 i_pae 0.49 con 0.70 i_con 3.87 plddt 0.48 ptm 0.73 i_ptm 0.23
# 87 models [2] recycles 1 hard 0 soft 1 temp 0.54 loss 3.29 helix 0.56 pae 0.52 i_pae 0.54 con 0.67 i_con 4.00 plddt 0.43 ptm 0.72 i_ptm 0.18
# 88 models [4] recycles 1 hard 0 soft 1 temp 0.51 loss 3.21 helix 0.58 pae 0.46 i_pae 0.49 con 0.71 i_con 3.88 plddt 0.49 ptm 0.75 i_ptm 0.25
# 89 models [0] recycles 1 hard 0 soft 1 temp 0.48 loss 2.99 helix 0.49 pae 0.41 i_pae 0.42 con 0.62 i_con 3.76 plddt 0.51 ptm 0.75 i_ptm 0.29
# 90 models [4] recycles 1 hard 0 soft 1 temp 0.45 loss 3.49 helix 0.60 pae 0.56 i_pae 0.59 con 0.87 i_con 4.09 plddt 0.43 ptm 0.73 i_ptm 0.16
# 91 models [2] recycles 1 hard 0 soft 1 temp 0.42 loss 3.06 helix 0.45 pae 0.46 i_pae 0.49 con 0.64 i_con 3.88 plddt 0.49 ptm 0.72 i_ptm 0.25
# 92 models [3] recycles 1 hard 0 soft 1 temp 0.39 loss 3.04 helix 0.44 pae 0.45 i_pae 0.48 con 0.65 i_con 3.85 plddt 0.50 ptm 0.74 i_ptm 0.23
# 93 models [4] recycles 1 hard 0 soft 1 temp 0.37 loss 2.93 helix 0.48 pae 0.39 i_pae 0.41 con 0.64 i_con 3.69 plddt 0.59 ptm 0.76 i_ptm 0.34
# 94 models [1] recycles 1 hard 0 soft 1 temp 0.34 loss 3.51 helix 0.73 pae 0.52 i_pae 0.54 con 0.76 i_con 4.04 plddt 0.43 ptm 0.75 i_ptm 0.18
# 95 models [1] recycles 1 hard 0 soft 1 temp 0.32 loss 2.83 helix 0.50 pae 0.32 i_pae 0.34 con 0.61 i_con 3.56 plddt 0.60 ptm 0.77 i_ptm 0.41
# 96 models [3] recycles 1 hard 0 soft 1 temp 0.29 loss 2.91 helix 0.42 pae 0.41 i_pae 0.43 con 0.59 i_con 3.77 plddt 0.54 ptm 0.75 i_ptm 0.29
# 97 models [4] recycles 1 hard 0 soft 1 temp 0.27 loss 2.88 helix 0.49 pae 0.36 i_pae 0.38 con 0.66 i_con 3.60 plddt 0.61 ptm 0.76 i_ptm 0.40
# 98 models [1] recycles 1 hard 0 soft 1 temp 0.25 loss 3.28 helix 0.57 pae 0.47 i_pae 0.51 con 0.75 i_con 3.96 plddt 0.47 ptm 0.75 i_ptm 0.23
# 99 models [1] recycles 1 hard 0 soft 1 temp 0.23 loss 2.76 helix 0.41 pae 0.35 i_pae 0.37 con 0.53 i_con 3.64 plddt 0.58 ptm 0.76 i_ptm 0.37
# 100 models [3] recycles 1 hard 0 soft 1 temp 0.21 loss 3.07 helix 0.48 pae 0.43 i_pae 0.45 con 0.72 i_con 3.82 plddt 0.53 ptm 0.75 i_ptm 0.29
# 101 models [4] recycles 1 hard 0 soft 1 temp 0.19 loss 3.17 helix 0.57 pae 0.45 i_pae 0.47 con 0.73 i_con 3.82 plddt 0.50 ptm 0.75 i_ptm 0.27
# 102 models [3] recycles 1 hard 0 soft 1 temp 0.17 loss 2.97 helix 0.45 pae 0.41 i_pae 0.44 con 0.66 i_con 3.77 plddt 0.50 ptm 0.74 i_ptm 0.31
# 103 models [3] recycles 1 hard 0 soft 1 temp 0.15 loss 2.99 helix 0.48 pae 0.40 i_pae 0.42 con 0.69 i_con 3.72 plddt 0.54 ptm 0.74 i_ptm 0.32
# 104 models [0] recycles 1 hard 0 soft 1 temp 0.14 loss 3.14 helix 0.64 pae 0.42 i_pae 0.44 con 0.62 i_con 3.77 plddt 0.51 ptm 0.74 i_ptm 0.28
# 105 models [3] recycles 1 hard 0 soft 1 temp 0.12 loss 3.53 helix 0.50 pae 0.60 i_pae 0.66 con 0.72 i_con 4.44 plddt 0.42 ptm 0.73 i_ptm 0.13
# 106 models [4] recycles 1 hard 0 soft 1 temp 0.11 loss 2.68 helix 0.43 pae 0.30 i_pae 0.31 con 0.60 i_con 3.44 plddt 0.66 ptm 0.78 i_ptm 0.46
# 107 models [4] recycles 1 hard 0 soft 1 temp 0.09 loss 3.35 helix 0.60 pae 0.51 i_pae 0.55 con 0.75 i_con 4.00 plddt 0.47 ptm 0.74 i_ptm 0.22
# 108 models [3] recycles 1 hard 0 soft 1 temp 0.08 loss 3.59 helix 0.50 pae 0.65 i_pae 0.71 con 0.81 i_con 4.41 plddt 0.41 ptm 0.73 i_ptm 0.09
# 109 models [0] recycles 1 hard 0 soft 1 temp 0.07 loss 3.35 helix 0.69 pae 0.46 i_pae 0.47 con 0.80 i_con 3.84 plddt 0.46 ptm 0.74 i_ptm 0.23
# 110 models [2] recycles 1 hard 0 soft 1 temp 0.06 loss 3.50 helix 0.78 pae 0.48 i_pae 0.50 con 0.81 i_con 3.93 plddt 0.46 ptm 0.74 i_ptm 0.25
# 111 models [0] recycles 1 hard 0 soft 1 temp 0.05 loss 3.03 helix 0.57 pae 0.38 i_pae 0.40 con 0.69 i_con 3.67 plddt 0.55 ptm 0.76 i_ptm 0.32
# 112 models [4] recycles 1 hard 0 soft 1 temp 0.04 loss 3.13 helix 0.52 pae 0.44 i_pae 0.47 con 0.74 i_con 3.82 plddt 0.52 ptm 0.75 i_ptm 0.29
# 113 models [1] recycles 1 hard 0 soft 1 temp 0.03 loss 2.65 helix 0.38 pae 0.30 i_pae 0.32 con 0.57 i_con 3.51 plddt 0.62 ptm 0.76 i_ptm 0.45
# 114 models [0] recycles 1 hard 0 soft 1 temp 0.03 loss 3.19 helix 0.66 pae 0.42 i_pae 0.44 con 0.68 i_con 3.75 plddt 0.51 ptm 0.75 i_ptm 0.28
# 115 models [2] recycles 1 hard 0 soft 1 temp 0.02 loss 3.37 helix 0.64 pae 0.51 i_pae 0.55 con 0.71 i_con 3.99 plddt 0.45 ptm 0.73 i_ptm 0.20
# 116 models [0] recycles 1 hard 0 soft 1 temp 0.02 loss 3.11 helix 0.60 pae 0.39 i_pae 0.40 con 0.73 i_con 3.71 plddt 0.53 ptm 0.75 i_ptm 0.31
# 117 models [4] recycles 1 hard 0 soft 1 temp 0.01 loss 3.23 helix 0.65 pae 0.43 i_pae 0.45 con 0.75 i_con 3.79 plddt 0.52 ptm 0.76 i_ptm 0.29
# 118 models [4] recycles 1 hard 0 soft 1 temp 0.01 loss 2.75 helix 0.53 pae 0.29 i_pae 0.31 con 0.63 i_con 3.40 plddt 0.66 ptm 0.78 i_ptm 0.50
# 119 models [4] recycles 1 hard 0 soft 1 temp 0.01 loss 2.74 helix 0.46 pae 0.32 i_pae 0.34 con 0.58 i_con 3.50 plddt 0.64 ptm 0.77 i_ptm 0.44
# 120 models [3] recycles 1 hard 0 soft 1 temp 0.01 loss 3.05 helix 0.46 pae 0.45 i_pae 0.48 con 0.66 i_con 3.84 plddt 0.46 ptm 0.75 i_ptm 0.25
# Stage 3: running (hard)
# 121 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 2.86 helix 0.48 pae 0.35 i_pae 0.37 con 0.60 i_con 3.62 plddt 0.54 ptm 0.77 i_ptm 0.37
# 122 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 2.80 helix 0.46 pae 0.33 i_pae 0.36 con 0.62 i_con 3.55 plddt 0.57 ptm 0.77 i_ptm 0.41
# 123 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 3.01 helix 0.50 pae 0.41 i_pae 0.44 con 0.65 i_con 3.76 plddt 0.52 ptm 0.76 i_ptm 0.33
# 124 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 2.86 helix 0.48 pae 0.35 i_pae 0.37 con 0.60 i_con 3.62 plddt 0.54 ptm 0.77 i_ptm 0.37
# 125 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 3.01 helix 0.50 pae 0.41 i_pae 0.44 con 0.65 i_con 3.76 plddt 0.52 ptm 0.76 i_ptm 0.33
# Trajectory starting confidence low, skipping analysis and MPNN optimisation
#
# Starting trajectory took: 0 hours, 2 minutes, 34 seconds
#
# Starting trajectory: BMPR1A_l21_s156199
# Stage 1: running (logits → soft)
# 1 models [4] recycles 0 hard 0 soft 0.01 temp 1 loss 6.20 helix 1.55 pae 0.55 i_pae 0.57 con 4.64 i_con 3.93 plddt 0.33 ptm 0.69 i_ptm 0.17
# 2 models [4] recycles 0 hard 0 soft 0.03 temp 1 loss 5.81 helix 0.99 pae 0.58 i_pae 0.63 con 4.75 i_con 4.07 plddt 0.37 ptm 0.67 i_ptm 0.14
# 3 models [4] recycles 0 hard 0 soft 0.04 temp 1 loss 6.00 helix 1.02 pae 0.61 i_pae 0.68 con 4.89 i_con 4.18 plddt 0.31 ptm 0.67 i_ptm 0.10
# 4 models [1] recycles 0 hard 0 soft 0.05 temp 1 loss 5.85 helix 0.72 pae 0.60 i_pae 0.70 con 5.02 i_con 4.32 plddt 0.37 ptm 0.66 i_ptm 0.08
# 5 models [2] recycles 0 hard 0 soft 0.07 temp 1 loss 5.64 helix 0.35 pae 0.59 i_pae 0.71 con 5.22 i_con 4.45 plddt 0.49 ptm 0.64 i_ptm 0.09
# 6 models [4] recycles 0 hard 0 soft 0.08 temp 1 loss 5.29 helix 0.51 pae 0.54 i_pae 0.62 con 4.72 i_con 4.00 plddt 0.42 ptm 0.66 i_ptm 0.13
# 7 models [3] recycles 0 hard 0 soft 0.09 temp 1 loss 5.67 helix 0.91 pae 0.59 i_pae 0.65 con 4.64 i_con 4.02 plddt 0.34 ptm 0.66 i_ptm 0.11
# 8 models [2] recycles 0 hard 0 soft 0.11 temp 1 loss 5.48 helix 0.48 pae 0.56 i_pae 0.67 con 4.79 i_con 4.35 plddt 0.48 ptm 0.63 i_ptm 0.11
# 9 models [1] recycles 0 hard 0 soft 0.12 temp 1 loss 5.52 helix 0.49 pae 0.55 i_pae 0.64 con 4.76 i_con 4.46 plddt 0.46 ptm 0.66 i_ptm 0.10
# 10 models [4] recycles 0 hard 0 soft 0.13 temp 1 loss 5.49 helix 0.54 pae 0.60 i_pae 0.69 con 4.77 i_con 4.21 plddt 0.42 ptm 0.66 i_ptm 0.09
# 11 models [1] recycles 0 hard 0 soft 0.15 temp 1 loss 5.28 helix 0.36 pae 0.53 i_pae 0.62 con 4.70 i_con 4.31 plddt 0.47 ptm 0.67 i_ptm 0.11
# 12 models [2] recycles 0 hard 0 soft 0.16 temp 1 loss 5.22 helix 0.48 pae 0.59 i_pae 0.68 con 4.44 i_con 4.14 plddt 0.50 ptm 0.63 i_ptm 0.09
# 13 models [1] recycles 0 hard 0 soft 0.17 temp 1 loss 5.31 helix 0.38 pae 0.54 i_pae 0.64 con 4.58 i_con 4.45 plddt 0.51 ptm 0.66 i_ptm 0.11
# 14 models [1] recycles 0 hard 0 soft 0.19 temp 1 loss 5.18 helix 0.48 pae 0.54 i_pae 0.63 con 4.27 i_con 4.31 plddt 0.49 ptm 0.67 i_ptm 0.11
# 15 models [3] recycles 0 hard 0 soft 0.20 temp 1 loss 5.33 helix 0.62 pae 0.58 i_pae 0.67 con 4.32 i_con 4.22 plddt 0.43 ptm 0.65 i_ptm 0.09
# 16 models [3] recycles 0 hard 0 soft 0.21 temp 1 loss 5.15 helix 0.49 pae 0.59 i_pae 0.68 con 4.26 i_con 4.17 plddt 0.48 ptm 0.66 i_ptm 0.08
# 17 models [3] recycles 0 hard 0 soft 0.23 temp 1 loss 5.04 helix 0.43 pae 0.57 i_pae 0.67 con 4.27 i_con 4.08 plddt 0.50 ptm 0.65 i_ptm 0.09
# 18 models [1] recycles 0 hard 0 soft 0.24 temp 1 loss 5.34 helix 0.38 pae 0.57 i_pae 0.68 con 4.64 i_con 4.42 plddt 0.55 ptm 0.65 i_ptm 0.08
# 19 models [0] recycles 0 hard 0 soft 0.25 temp 1 loss 5.18 helix 0.36 pae 0.56 i_pae 0.65 con 4.65 i_con 4.15 plddt 0.54 ptm 0.65 i_ptm 0.09
# 20 models [4] recycles 0 hard 0 soft 0.27 temp 1 loss 5.24 helix 0.38 pae 0.56 i_pae 0.65 con 4.78 i_con 4.09 plddt 0.51 ptm 0.66 i_ptm 0.11
# 21 models [1] recycles 0 hard 0 soft 0.28 temp 1 loss 5.41 helix 0.55 pae 0.54 i_pae 0.62 con 4.58 i_con 4.33 plddt 0.49 ptm 0.68 i_ptm 0.11
# 22 models [1] recycles 0 hard 0 soft 0.29 temp 1 loss 5.01 helix 0.38 pae 0.53 i_pae 0.61 con 4.35 i_con 4.09 plddt 0.52 ptm 0.65 i_ptm 0.12
# 23 models [2] recycles 0 hard 0 soft 0.31 temp 1 loss 5.09 helix 0.45 pae 0.59 i_pae 0.67 con 4.26 i_con 4.13 plddt 0.50 ptm 0.65 i_ptm 0.10
# 24 models [1] recycles 0 hard 0 soft 0.32 temp 1 loss 4.81 helix 0.38 pae 0.51 i_pae 0.59 con 3.97 i_con 4.10 plddt 0.52 ptm 0.67 i_ptm 0.12
# 25 models [3] recycles 0 hard 0 soft 0.33 temp 1 loss 5.00 helix 0.49 pae 0.57 i_pae 0.65 con 4.12 i_con 4.04 plddt 0.48 ptm 0.65 i_ptm 0.10
# 26 models [2] recycles 0 hard 0 soft 0.35 temp 1 loss 5.03 helix 0.48 pae 0.59 i_pae 0.68 con 4.05 i_con 4.17 plddt 0.53 ptm 0.65 i_ptm 0.09
# 27 models [4] recycles 0 hard 0 soft 0.36 temp 1 loss 5.14 helix 0.36 pae 0.55 i_pae 0.64 con 4.64 i_con 4.06 plddt 0.49 ptm 0.65 i_ptm 0.12
# 28 models [3] recycles 0 hard 0 soft 0.37 temp 1 loss 4.88 helix 0.36 pae 0.55 i_pae 0.65 con 4.11 i_con 4.08 plddt 0.52 ptm 0.65 i_ptm 0.09
# 29 models [3] recycles 0 hard 0 soft 0.39 temp 1 loss 4.82 helix 0.39 pae 0.55 i_pae 0.64 con 3.97 i_con 4.05 plddt 0.50 ptm 0.65 i_ptm 0.10
# 30 models [4] recycles 0 hard 0 soft 0.40 temp 1 loss 4.92 helix 0.39 pae 0.52 i_pae 0.58 con 4.35 i_con 3.91 plddt 0.50 ptm 0.67 i_ptm 0.17
# 31 models [3] recycles 0 hard 0 soft 0.41 temp 1 loss 4.68 helix 0.39 pae 0.54 i_pae 0.62 con 3.79 i_con 3.96 plddt 0.51 ptm 0.65 i_ptm 0.11
# 32 models [2] recycles 0 hard 0 soft 0.43 temp 1 loss 4.94 helix 0.50 pae 0.57 i_pae 0.65 con 3.97 i_con 4.06 plddt 0.48 ptm 0.63 i_ptm 0.13
# 33 models [4] recycles 0 hard 0 soft 0.44 temp 1 loss 5.09 helix 0.41 pae 0.58 i_pae 0.68 con 4.35 i_con 4.12 plddt 0.49 ptm 0.66 i_ptm 0.10
# 34 models [0] recycles 0 hard 0 soft 0.45 temp 1 loss 4.88 helix 0.34 pae 0.48 i_pae 0.55 con 4.42 i_con 3.91 plddt 0.52 ptm 0.67 i_ptm 0.17
# 35 models [0] recycles 0 hard 0 soft 0.47 temp 1 loss 5.01 helix 0.36 pae 0.52 i_pae 0.60 con 4.50 i_con 4.00 plddt 0.48 ptm 0.66 i_ptm 0.13
# 36 models [2] recycles 0 hard 0 soft 0.48 temp 1 loss 4.98 helix 0.46 pae 0.57 i_pae 0.64 con 4.10 i_con 4.08 plddt 0.47 ptm 0.65 i_ptm 0.12
# 37 models [4] recycles 0 hard 0 soft 0.49 temp 1 loss 4.92 helix 0.50 pae 0.51 i_pae 0.56 con 4.20 i_con 3.85 plddt 0.43 ptm 0.68 i_ptm 0.18
# 38 models [3] recycles 1 hard 0 soft 0.51 temp 1 loss 4.97 helix 0.51 pae 0.52 i_pae 0.58 con 4.18 i_con 3.97 plddt 0.49 ptm 0.66 i_ptm 0.15
# 39 models [2] recycles 1 hard 0 soft 0.52 temp 1 loss 5.02 helix 0.63 pae 0.54 i_pae 0.59 con 4.02 i_con 3.95 plddt 0.45 ptm 0.63 i_ptm 0.16
# 40 models [1] recycles 1 hard 0 soft 0.53 temp 1 loss 5.03 helix 0.36 pae 0.50 i_pae 0.58 con 4.49 i_con 4.07 plddt 0.52 ptm 0.68 i_ptm 0.14
# 41 models [2] recycles 1 hard 0 soft 0.55 temp 1 loss 4.95 helix 0.48 pae 0.56 i_pae 0.63 con 4.08 i_con 4.02 plddt 0.49 ptm 0.64 i_ptm 0.11
# 42 models [2] recycles 1 hard 0 soft 0.56 temp 1 loss 4.96 helix 0.47 pae 0.56 i_pae 0.63 con 4.10 i_con 4.04 plddt 0.46 ptm 0.64 i_ptm 0.12
# 43 models [3] recycles 1 hard 0 soft 0.57 temp 1 loss 4.87 helix 0.49 pae 0.53 i_pae 0.59 con 4.01 i_con 3.95 plddt 0.52 ptm 0.67 i_ptm 0.14
# 44 models [3] recycles 1 hard 0 soft 0.59 temp 1 loss 4.90 helix 0.42 pae 0.58 i_pae 0.66 con 3.94 i_con 4.14 plddt 0.51 ptm 0.65 i_ptm 0.10
# 45 models [3] recycles 1 hard 0 soft 0.60 temp 1 loss 4.75 helix 0.40 pae 0.53 i_pae 0.60 con 3.96 i_con 3.93 plddt 0.52 ptm 0.66 i_ptm 0.13
# 46 models [1] recycles 1 hard 0 soft 0.61 temp 1 loss 5.09 helix 0.31 pae 0.52 i_pae 0.60 con 4.57 i_con 4.19 plddt 0.52 ptm 0.67 i_ptm 0.12
# 47 models [2] recycles 1 hard 0 soft 0.63 temp 1 loss 5.01 helix 0.69 pae 0.56 i_pae 0.60 con 3.86 i_con 3.97 plddt 0.42 ptm 0.65 i_ptm 0.14
# 48 models [3] recycles 1 hard 0 soft 0.64 temp 1 loss 4.88 helix 0.44 pae 0.57 i_pae 0.64 con 3.97 i_con 4.05 plddt 0.52 ptm 0.64 i_ptm 0.11
# 49 models [3] recycles 1 hard 0 soft 0.65 temp 1 loss 4.73 helix 0.54 pae 0.51 i_pae 0.56 con 3.78 i_con 3.85 plddt 0.50 ptm 0.67 i_ptm 0.18
# 50 models [0] recycles 1 hard 0 soft 0.67 temp 1 loss 4.84 helix 0.48 pae 0.49 i_pae 0.54 con 4.15 i_con 3.85 plddt 0.51 ptm 0.67 i_ptm 0.17
# 51 models [1] recycles 1 hard 0 soft 0.68 temp 1 loss 5.10 helix 0.44 pae 0.53 i_pae 0.61 con 4.07 i_con 4.45 plddt 0.51 ptm 0.68 i_ptm 0.12
# 52 models [3] recycles 1 hard 0 soft 0.69 temp 1 loss 5.06 helix 0.41 pae 0.58 i_pae 0.67 con 4.09 i_con 4.33 plddt 0.54 ptm 0.66 i_ptm 0.09
# 53 models [3] recycles 1 hard 0 soft 0.71 temp 1 loss 4.78 helix 0.48 pae 0.48 i_pae 0.53 con 4.07 i_con 3.81 plddt 0.54 ptm 0.66 i_ptm 0.20
# 54 models [3] recycles 1 hard 0 soft 0.72 temp 1 loss 4.79 helix 0.57 pae 0.50 i_pae 0.55 con 3.86 i_con 3.85 plddt 0.51 ptm 0.68 i_ptm 0.18
# 55 models [3] recycles 1 hard 0 soft 0.73 temp 1 loss 4.97 helix 0.61 pae 0.62 i_pae 0.70 con 3.60 i_con 4.20 plddt 0.44 ptm 0.65 i_ptm 0.08
# 56 models [1] recycles 1 hard 0 soft 0.75 temp 1 loss 5.02 helix 0.50 pae 0.55 i_pae 0.62 con 4.11 i_con 4.10 plddt 0.48 ptm 0.67 i_ptm 0.11
# 57 models [3] recycles 1 hard 0 soft 0.76 temp 1 loss 5.01 helix 0.66 pae 0.57 i_pae 0.62 con 3.87 i_con 4.00 plddt 0.46 ptm 0.66 i_ptm 0.11
# 58 models [4] recycles 1 hard 0 soft 0.77 temp 1 loss 4.88 helix 0.36 pae 0.53 i_pae 0.59 con 4.26 i_con 3.97 plddt 0.49 ptm 0.67 i_ptm 0.14
# 59 models [0] recycles 1 hard 0 soft 0.79 temp 1 loss 4.92 helix 0.47 pae 0.49 i_pae 0.55 con 4.31 i_con 3.83 plddt 0.51 ptm 0.67 i_ptm 0.17
# 60 models [2] recycles 1 hard 0 soft 0.80 temp 1 loss 5.18 helix 0.48 pae 0.60 i_pae 0.68 con 4.41 i_con 4.09 plddt 0.48 ptm 0.62 i_ptm 0.09
# 61 models [0] recycles 1 hard 0 soft 0.81 temp 1 loss 4.99 helix 0.44 pae 0.50 i_pae 0.56 con 4.46 i_con 3.88 plddt 0.46 ptm 0.68 i_ptm 0.15
# 62 models [1] recycles 1 hard 0 soft 0.83 temp 1 loss 4.88 helix 0.48 pae 0.49 i_pae 0.55 con 4.11 i_con 3.94 plddt 0.47 ptm 0.68 i_ptm 0.15
# 63 models [1] recycles 1 hard 0 soft 0.84 temp 1 loss 4.85 helix 0.48 pae 0.50 i_pae 0.56 con 4.04 i_con 3.92 plddt 0.46 ptm 0.68 i_ptm 0.14
# 64 models [1] recycles 1 hard 0 soft 0.85 temp 1 loss 4.84 helix 0.49 pae 0.50 i_pae 0.56 con 3.95 i_con 3.97 plddt 0.49 ptm 0.68 i_ptm 0.14
# 65 models [1] recycles 1 hard 0 soft 0.87 temp 1 loss 4.78 helix 0.35 pae 0.49 i_pae 0.56 con 4.17 i_con 3.92 plddt 0.51 ptm 0.68 i_ptm 0.14
# 66 models [3] recycles 1 hard 0 soft 0.88 temp 1 loss 4.81 helix 0.56 pae 0.53 i_pae 0.58 con 3.85 i_con 3.87 plddt 0.46 ptm 0.67 i_ptm 0.15
# 67 models [4] recycles 1 hard 0 soft 0.89 temp 1 loss 5.00 helix 0.67 pae 0.51 i_pae 0.54 con 4.08 i_con 3.83 plddt 0.47 ptm 0.68 i_ptm 0.19
# 68 models [1] recycles 1 hard 0 soft 0.91 temp 1 loss 4.98 helix 0.51 pae 0.52 i_pae 0.57 con 4.22 i_con 3.93 plddt 0.46 ptm 0.68 i_ptm 0.14
# 69 models [2] recycles 1 hard 0 soft 0.92 temp 1 loss 5.10 helix 0.81 pae 0.57 i_pae 0.62 con 3.82 i_con 3.94 plddt 0.44 ptm 0.64 i_ptm 0.14
# 70 models [0] recycles 1 hard 0 soft 0.93 temp 1 loss 5.02 helix 0.64 pae 0.53 i_pae 0.57 con 4.04 i_con 3.92 plddt 0.42 ptm 0.67 i_ptm 0.14
# 71 models [2] recycles 1 hard 0 soft 0.95 temp 1 loss 4.95 helix 0.57 pae 0.52 i_pae 0.57 con 4.10 i_con 3.88 plddt 0.47 ptm 0.65 i_ptm 0.16
# 72 models [4] recycles 1 hard 0 soft 0.96 temp 1 loss 5.03 helix 0.53 pae 0.51 i_pae 0.56 con 4.36 i_con 3.86 plddt 0.46 ptm 0.68 i_ptm 0.17
# 73 models [3] recycles 1 hard 0 soft 0.97 temp 1 loss 5.00 helix 0.81 pae 0.54 i_pae 0.58 con 3.72 i_con 3.88 plddt 0.42 ptm 0.67 i_ptm 0.16
# 74 models [2] recycles 1 hard 0 soft 0.99 temp 1 loss 5.03 helix 0.69 pae 0.54 i_pae 0.59 con 3.97 i_con 3.92 plddt 0.45 ptm 0.63 i_ptm 0.16
# 75 models [2] recycles 1 hard 0 soft 1 temp 1 loss 4.89 helix 0.60 pae 0.53 i_pae 0.58 con 3.91 i_con 3.88 plddt 0.45 ptm 0.65 i_ptm 0.15
# Stage 2: running (soft → hard)
# 76 models [4] recycles 1 hard 0 soft 1 temp 0.96 loss 4.95 helix 0.61 pae 0.51 i_pae 0.55 con 4.08 i_con 3.83 plddt 0.47 ptm 0.68 i_ptm 0.19
# 77 models [3] recycles 1 hard 0 soft 1 temp 0.91 loss 4.95 helix 0.58 pae 0.57 i_pae 0.62 con 3.89 i_con 4.01 plddt 0.43 ptm 0.67 i_ptm 0.12
# 78 models [2] recycles 1 hard 0 soft 1 temp 0.87 loss 4.96 helix 0.61 pae 0.55 i_pae 0.61 con 3.89 i_con 3.98 plddt 0.45 ptm 0.65 i_ptm 0.14
# 79 models [2] recycles 1 hard 0 soft 1 temp 0.83 loss 4.98 helix 0.55 pae 0.55 i_pae 0.61 con 4.05 i_con 3.98 plddt 0.48 ptm 0.65 i_ptm 0.13
# 80 models [1] recycles 1 hard 0 soft 1 temp 0.79 loss 5.14 helix 0.64 pae 0.53 i_pae 0.58 con 4.21 i_con 3.99 plddt 0.43 ptm 0.68 i_ptm 0.13
# 81 models [1] recycles 1 hard 0 soft 1 temp 0.75 loss 4.92 helix 0.49 pae 0.52 i_pae 0.57 con 4.14 i_con 3.93 plddt 0.46 ptm 0.67 i_ptm 0.14
# 82 models [4] recycles 1 hard 0 soft 1 temp 0.72 loss 4.95 helix 0.54 pae 0.52 i_pae 0.58 con 4.14 i_con 3.89 plddt 0.49 ptm 0.67 i_ptm 0.16
# 83 models [4] recycles 1 hard 0 soft 1 temp 0.68 loss 4.97 helix 0.72 pae 0.53 i_pae 0.56 con 3.90 i_con 3.84 plddt 0.44 ptm 0.69 i_ptm 0.18
# 84 models [0] recycles 1 hard 0 soft 1 temp 0.64 loss 4.94 helix 0.47 pae 0.53 i_pae 0.59 con 4.24 i_con 3.90 plddt 0.46 ptm 0.66 i_ptm 0.14
# 85 models [3] recycles 1 hard 0 soft 1 temp 0.61 loss 4.83 helix 0.54 pae 0.53 i_pae 0.58 con 3.87 i_con 3.90 plddt 0.48 ptm 0.67 i_ptm 0.15
# 86 models [0] recycles 1 hard 0 soft 1 temp 0.58 loss 5.05 helix 0.72 pae 0.54 i_pae 0.59 con 3.95 i_con 3.92 plddt 0.43 ptm 0.66 i_ptm 0.15
# 87 models [4] recycles 1 hard 0 soft 1 temp 0.54 loss 4.93 helix 0.46 pae 0.54 i_pae 0.60 con 4.15 i_con 3.97 plddt 0.46 ptm 0.67 i_ptm 0.14
# 88 models [0] recycles 1 hard 0 soft 1 temp 0.51 loss 4.97 helix 0.57 pae 0.52 i_pae 0.57 con 4.13 i_con 3.88 plddt 0.44 ptm 0.67 i_ptm 0.15
# 89 models [4] recycles 1 hard 0 soft 1 temp 0.48 loss 4.98 helix 0.66 pae 0.57 i_pae 0.62 con 3.82 i_con 3.99 plddt 0.43 ptm 0.67 i_ptm 0.13
# 90 models [1] recycles 1 hard 0 soft 1 temp 0.45 loss 5.20 helix 0.78 pae 0.52 i_pae 0.57 con 4.17 i_con 3.90 plddt 0.43 ptm 0.68 i_ptm 0.15
# 91 models [0] recycles 1 hard 0 soft 1 temp 0.42 loss 4.99 helix 0.74 pae 0.52 i_pae 0.56 con 3.87 i_con 3.86 plddt 0.42 ptm 0.68 i_ptm 0.16
# 92 models [0] recycles 1 hard 0 soft 1 temp 0.39 loss 5.02 helix 0.72 pae 0.53 i_pae 0.57 con 3.91 i_con 3.90 plddt 0.43 ptm 0.67 i_ptm 0.15
# 93 models [3] recycles 1 hard 0 soft 1 temp 0.37 loss 4.79 helix 0.50 pae 0.54 i_pae 0.59 con 3.82 i_con 3.94 plddt 0.47 ptm 0.68 i_ptm 0.14
# 94 models [3] recycles 1 hard 0 soft 1 temp 0.34 loss 4.96 helix 0.61 pae 0.58 i_pae 0.64 con 3.79 i_con 4.03 plddt 0.43 ptm 0.65 i_ptm 0.10
# 95 models [3] recycles 1 hard 0 soft 1 temp 0.32 loss 4.88 helix 0.58 pae 0.58 i_pae 0.64 con 3.71 i_con 4.03 plddt 0.44 ptm 0.67 i_ptm 0.12
# 96 models [3] recycles 1 hard 0 soft 1 temp 0.29 loss 4.88 helix 0.51 pae 0.55 i_pae 0.62 con 3.91 i_con 4.00 plddt 0.50 ptm 0.66 i_ptm 0.12
# 97 models [1] recycles 1 hard 0 soft 1 temp 0.27 loss 5.06 helix 0.74 pae 0.50 i_pae 0.55 con 4.00 i_con 3.89 plddt 0.44 ptm 0.69 i_ptm 0.17
# 98 models [4] recycles 1 hard 0 soft 1 temp 0.25 loss 4.98 helix 0.42 pae 0.55 i_pae 0.63 con 4.25 i_con 4.03 plddt 0.51 ptm 0.67 i_ptm 0.13
# 99 models [0] recycles 1 hard 0 soft 1 temp 0.23 loss 4.97 helix 0.63 pae 0.51 i_pae 0.56 con 4.03 i_con 3.89 plddt 0.46 ptm 0.67 i_ptm 0.16
# 100 models [0] recycles 1 hard 0 soft 1 temp 0.21 loss 4.93 helix 0.50 pae 0.51 i_pae 0.57 con 4.18 i_con 3.91 plddt 0.50 ptm 0.67 i_ptm 0.15
# 101 models [3] recycles 1 hard 0 soft 1 temp 0.19 loss 4.93 helix 0.40 pae 0.55 i_pae 0.63 con 4.16 i_con 4.05 plddt 0.50 ptm 0.66 i_ptm 0.11
# 102 models [3] recycles 1 hard 0 soft 1 temp 0.17 loss 4.86 helix 0.51 pae 0.55 i_pae 0.61 con 3.93 i_con 3.96 plddt 0.48 ptm 0.67 i_ptm 0.13
# 103 models [1] recycles 1 hard 0 soft 1 temp 0.15 loss 5.07 helix 0.73 pae 0.53 i_pae 0.58 con 3.96 i_con 3.93 plddt 0.42 ptm 0.68 i_ptm 0.14
# 104 models [1] recycles 1 hard 0 soft 1 temp 0.14 loss 4.96 helix 0.47 pae 0.54 i_pae 0.61 con 4.13 i_con 4.02 plddt 0.49 ptm 0.66 i_ptm 0.12
# 105 models [2] recycles 1 hard 0 soft 1 temp 0.12 loss 5.00 helix 0.59 pae 0.62 i_pae 0.70 con 3.77 i_con 4.15 plddt 0.47 ptm 0.63 i_ptm 0.09
# 106 models [0] recycles 1 hard 0 soft 1 temp 0.11 loss 5.05 helix 0.54 pae 0.53 i_pae 0.59 con 4.28 i_con 3.95 plddt 0.48 ptm 0.67 i_ptm 0.14
# 107 models [1] recycles 1 hard 0 soft 1 temp 0.09 loss 4.98 helix 0.46 pae 0.49 i_pae 0.56 con 4.34 i_con 3.95 plddt 0.51 ptm 0.66 i_ptm 0.16
# 108 models [4] recycles 1 hard 0 soft 1 temp 0.08 loss 5.01 helix 0.47 pae 0.54 i_pae 0.61 con 4.27 i_con 3.99 plddt 0.49 ptm 0.68 i_ptm 0.14
# 109 models [2] recycles 1 hard 0 soft 1 temp 0.07 loss 5.05 helix 0.54 pae 0.56 i_pae 0.63 con 4.16 i_con 4.03 plddt 0.48 ptm 0.64 i_ptm 0.11
# 110 models [1] recycles 1 hard 0 soft 1 temp 0.06 loss 4.90 helix 0.42 pae 0.52 i_pae 0.59 con 4.18 i_con 3.99 plddt 0.51 ptm 0.68 i_ptm 0.13
# 111 models [3] recycles 1 hard 0 soft 1 temp 0.05 loss 4.77 helix 0.56 pae 0.55 i_pae 0.59 con 3.69 i_con 3.93 plddt 0.48 ptm 0.66 i_ptm 0.14
# 112 models [0] recycles 1 hard 0 soft 1 temp 0.04 loss 5.05 helix 0.48 pae 0.53 i_pae 0.61 con 4.35 i_con 4.00 plddt 0.51 ptm 0.66 i_ptm 0.13
# 113 models [1] recycles 1 hard 0 soft 1 temp 0.03 loss 4.92 helix 0.44 pae 0.52 i_pae 0.59 con 4.19 i_con 3.98 plddt 0.50 ptm 0.68 i_ptm 0.13
# 114 models [3] recycles 1 hard 0 soft 1 temp 0.03 loss 4.78 helix 0.46 pae 0.53 i_pae 0.59 con 3.90 i_con 3.96 plddt 0.53 ptm 0.67 i_ptm 0.14
# 115 models [3] recycles 1 hard 0 soft 1 temp 0.02 loss 4.82 helix 0.42 pae 0.55 i_pae 0.62 con 4.00 i_con 3.98 plddt 0.55 ptm 0.66 i_ptm 0.12
# 116 models [0] recycles 1 hard 0 soft 1 temp 0.02 loss 4.84 helix 0.41 pae 0.51 i_pae 0.58 con 4.11 i_con 3.96 plddt 0.51 ptm 0.67 i_ptm 0.14
# 117 models [4] recycles 1 hard 0 soft 1 temp 0.01 loss 4.98 helix 0.38 pae 0.55 i_pae 0.63 con 4.32 i_con 4.04 plddt 0.54 ptm 0.67 i_ptm 0.13
# 118 models [2] recycles 1 hard 0 soft 1 temp 0.01 loss 5.00 helix 0.56 pae 0.60 i_pae 0.66 con 3.91 i_con 4.08 plddt 0.47 ptm 0.65 i_ptm 0.11
# 119 models [1] recycles 1 hard 0 soft 1 temp 0.01 loss 5.04 helix 0.47 pae 0.57 i_pae 0.64 con 4.13 i_con 4.16 plddt 0.47 ptm 0.66 i_ptm 0.11
# 120 models [3] recycles 1 hard 0 soft 1 temp 0.01 loss 4.88 helix 0.52 pae 0.59 i_pae 0.67 con 3.76 i_con 4.06 plddt 0.45 ptm 0.66 i_ptm 0.10
# Stage 3: running (hard)
# 121 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 5.02 helix 0.57 pae 0.52 i_pae 0.57 con 4.20 i_con 3.92 plddt 0.43 ptm 0.68 i_ptm 0.16
# 122 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 5.13 helix 0.44 pae 0.51 i_pae 0.58 con 4.62 i_con 3.96 plddt 0.47 ptm 0.68 i_ptm 0.15
# 123 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 5.02 helix 0.57 pae 0.52 i_pae 0.57 con 4.20 i_con 3.92 plddt 0.43 ptm 0.68 i_ptm 0.16
# 124 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 5.09 helix 0.50 pae 0.52 i_pae 0.58 con 4.43 i_con 3.95 plddt 0.45 ptm 0.68 i_ptm 0.15
# 125 models [0, 1, 2, 3, 4] recycles 1 hard 1 soft 1 temp 0.01 loss 4.99 helix 0.56 pae 0.52 i_pae 0.57 con 4.15 i_con 3.92 plddt 0.43 ptm 0.68 i_ptm 0.16
# Trajectory starting confidence low, skipping analysis and MPNN optimisation
#
# Starting trajectory took: 0 hours, 2 minutes, 18 seconds
#
# Starting trajectory: BMPR1A_l23_s769139
# Stage 1: running (logits → soft)

# %%
#@title Consolidate & Rank Designs
#@markdown ---
accepted_binders = [f for f in os.listdir(design_paths["Accepted"]) if f.endswith('.pdb')]

for f in os.listdir(design_paths["Accepted/Ranked"]):
    os.remove(os.path.join(design_paths["Accepted/Ranked"], f))

# load dataframe of designed binders
design_df = pd.read_csv(mpnn_csv)
design_df = design_df.sort_values('Average_i_pTM', ascending=False)

# create final csv dataframe to copy matched rows, initialize with the column labels
final_df = pd.DataFrame(columns=final_labels)

# check the ranking of the designs and copy them with new ranked IDs to the folder
rank = 1
for _, row in design_df.iterrows():
    for binder in accepted_binders:
        target_settings["binder_name"], model = binder.rsplit('_model', 1)
        if target_settings["binder_name"] == row['Design']:
            # rank and copy into ranked folder
            row_data = {'Rank': rank, **{label: row[label] for label in design_labels}}
            final_df = pd.concat([final_df, pd.DataFrame([row_data])], ignore_index=True)
            old_path = os.path.join(design_paths["Accepted"], binder)
            new_path = os.path.join(design_paths["Accepted/Ranked"], f"{rank}_{target_settings['binder_name']}_model{model.rsplit('.', 1)[0]}.pdb")
            shutil.copyfile(old_path, new_path)

            rank += 1
            break

# save the final_df to final_csv
final_df.to_csv(final_csv, index=False)

print("Designs ranked and final_designs_stats.csv generated")

# %%
#@title Top 20 Designs
df = pd.read_csv(os.path.join(design_path, 'final_design_stats.csv'))
df.head(20)

# %%
#@title Top Design Display
import py3Dmol
import glob
from IPython.display import HTML

#### pymol top design
top_design_dir = os.path.join(design_path, 'Accepted', 'Ranked')
top_design_pdb = glob.glob(os.path.join(top_design_dir, '1_*.pdb'))[0]

# Visualise in PyMOL
view = py3Dmol.view()
view.addModel(open(top_design_pdb, 'r').read(),'pdb')
view.setBackgroundColor('white')
view.setStyle({'chain':'A'}, {'cartoon': {'color':'#3c5b6f'}})
view.setStyle({'chain':'B'}, {'cartoon': {'color':'#B76E79'}})
view.zoomTo()
view.show()

# %%
#@title Display animation
import glob
from IPython.display import HTML

#### pymol top design
top_design_dir = os.path.join(design_path, 'Accepted', 'Ranked')
top_design_pdb = glob.glob(os.path.join(top_design_dir, '1_*.pdb'))[0]

top_design_name = os.path.basename(top_design_pdb).split('1_', 1)[1].split('_mpnn')[0]
top_design_animation = os.path.join(design_path, 'Accepted', 'Animation', f"{top_design_name}.html")

# Show animation
HTML(top_design_animation)
